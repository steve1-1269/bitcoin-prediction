# %%
import pandas as pd
import matplotlib.pyplot as plt
import joblib

# %%
model= joblib.load(r"C:\Users\MINE\Desktop\bitcoin prediction\expo_smoo.pkl")

# %%
df= pd.read_csv(r"C:\Users\MINE\Desktop\bitcoin prediction\train.csv")

# %%
df.head()
# Out:
#          Date      Y   Open   High    Low   Vol. Change %
# 0  2015-01-01  313.9  317.5  317.5  312.9  0.93K   -0.99%
# 1  2015-01-02  315.1  313.6  316.0  313.0  1.32K    0.40%
# 2  2015-01-05  273.2  261.0  276.5  260.5  2.68K    5.57%
# 3  2015-01-06  285.4  273.2  287.8  268.5  6.86K    4.46%
# 4  2015-01-07  297.0  286.1  303.8  285.0  1.53K    4.07%

# %%
df.set_index('Date', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2870 entries, 2015-01-01 to 2025-12-31
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Y         2861 non-null   float64
#  1   Open      2861 non-null   float64
#  2   High      2861 non-null   float64
#  3   Low       2861 non-null   float64
#  4   Vol.      2861 non-null   object
#  5   Change %  2861 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 157.0+ KB

# %%
df.index= pd.to_datetime(df.index)

# %%
# Predicting the next 50 days price 

predictions= model.forecast(50)

# %%
predictions
# Out:
# 2026-01-01    86581.046615
# 2026-01-02    85153.645657
# 2026-01-05    95588.726982
# 2026-01-06    90697.557878
# 2026-01-07    91046.015043
# 2026-01-08    86988.874714
# 2026-01-09    87679.274476
# 2026-01-12    83538.046982
# 2026-01-13    84320.174084
# 2026-01-14    86884.043616
# 2026-01-15    88219.790451
# 2026-01-16    86878.017771
# 2026-01-19    83265.745743
# 2026-01-20    82645.628648
# 2026-01-21    84903.694745
# 2026-01-22    83788.003599
# 2026-01-23    84513.088146
# 2026-01-26    81487.794691
# 2026-01-27    80689.341520
# 2026-01-28    81581.748660
# 2026-01-29    79555.791264
# 2026-01-30    79848.552213
# 2026-02-02    77203.574278
# 2026-02-03    76293.152607
# 2026-02-04    77889.506802
# 2026-02-05    75759.563611
# 2026-02-06    75983.083744
# 2026-02-09    77823.673200
# 2026-02-10    77397.720724
# 2026-02-11    73477.340300
# 2026-02-12    71884.836057
# 2026-02-13    72250.966874
# 2026-02-16    70191.653843
# 2026-02-17    72112.446193
# ...

# %%
plt.figure(figsize=(10,4))
plt.plot(df.Y.loc['2025'], label= 'Train')
plt.plot(predictions, label= 'predictions')

plt.tight_layout()
plt.legend()
plt.show()
